# %% [markdown]
# # Вебинар №4: Работа с файлами и модулями
#
# ## Python, базовый курс
#
# > Каширин Александр

# %% [markdown]
# # 1. Файловая система

# %% [markdown]
# Работа с файлами играет большую роль в программировании. Поэтому в этом уроке мы будем учиться читать данные из файлов, а также записывать данные в некоторый файл. Но для начала, пара слов о том что такое файловая система.
#
# **Файловая система** - порядок организации данных на компьютерах или других цифровых устройствах. Простыми словами, открывая любую папку на вашем компьютере, вы взаимодействуете с файловой системой вашего компьютера.
#
# Работая в Google Colab, вы не имеете прямого доступа к файлам своего компьютера, как например можете иметь при работе с PyCharm или VSCode. Однако, Google Colab дает вам возможность создавать виртуальное сессионное хранилище и загружать в него файлы. Также есть возможность подключать Google Drive и взаимодействовать с файловой системой облачного диска.
#
# Для того чтобы воспользоваться данным функционалом, нажмите на значок 📁. Далее вы увидите раскрывающееся окно:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Меню файловой системы Google Colab:
#
# 1.   Открыть меню файловой системы
# 2.   Загрузить файл в сессионное хранилище (загруженные файлы будут доступны только для данного ноутбука)
# 3.   Подключить диск (файлы будут подгружаться автоматически на облачный диск Google) Внимание, будьте уверены, что на вашем аккаунте гугл есть подключенный Google Drive!

# %% [markdown]
# ### Задача 1. Создание и загрузка файла
# Откройте файловый менеджер своего компьютера. Если вы работаете на Windows, то можете открыть любую удобную вам папку. Создайте в этой папке текстовый документ с названием `test_file`. Откройте этот файл на своем компьютере при помощи блокнота или любой другой программы, работающей с форматом `.txt`. Напишите в данный файл следующий текст в две **строки**:
#
#
# > Мне нравится программировать на Python и решать алгоритмические задачки!
#
# > У меня обязательно все получится!
#
# Далее в Google Colab в меню файловой системы нажмите на кнопку `Загрузить в сессионное хранилище`. Выберите только что созданный Вами файл `test_file` на вашем компьютере и загрузите его на платформу. Обратите внимание на предупреждение, которое выдает Google Colab. О чем оно говорит?
#
# После успешной загрузки, отройте файл из меню, два раза нажав на ЛКМ (левая кнопка мыши).
#
# ![image.png](data:image/png;base64,...)
#
# Если все прошло успешно, то вы молодец и выполнили первое задание!

# %% [markdown]
# ### Задача 2. Подкючение Google Drive
# Найдите вкладку наверху страницы с названием `Среда выполнения`, затем нажмите `Отключиться от среды выполнения и удалить ее`. Что произошло с Вашим файлом?
# Google Colab удаляет все файлы из хранилища вместе со всеми расчетами, произведенными в вашей программе. Чтобы такого не происходило, безопаснее подключать Google Drive. Давайте так и поступим!
#
# В меню файловой системы нажмите на кнопку `Подключить Google Drive`. Это займет некоторое время.
#
# Если все прошло успешно, то в меню файловой системы вам будет доступна новая вкладка *drive*. Если вы раскроете её, то увидите все папки и файлы, которые хранятся на вашем гугл-диске. О том как работать с Google Drive, создавать папки и перетаскивать в него файлы можно познакомится вот [тут](https://www.youtube.com/watch?v=wvfk8tWwVWg&ab_channel=%D0%9C%D0%BE%D0%B1%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9%D0%9C%D0%B8%D1%80).
#
# ![image.png](data:image/png;base64,...)
#
# После того как вы успешно подключили Google Drive, создайте в нем папку с любым понятным Вам названием, с которой вы будете взаимодействовать в течении этого урока. Я назову свою папку `Python 4. Работа с файлами и модулями`, а затем в эту папку помещу раннее созданный на моем компьютере файл `test_file`.
#
# Если у вас все получилось, то вы должны увидеть примерно вот такую структуру в вашем меню:
# ![image.png](data:image/png;base64,...)
#
# Замечательно, теперь если что-то случится с колабом, то ваши файлы будут защищены лучше от непредвиденных ситуаций.

# %% [markdown]
# # 2. Чтение и запись данных

# %% [markdown]
# ## Открытие файла
# Чтобы взаимодействовать с файлом в Python, необходимо этот файл сначала **открыть**. Для этого воспользуемся функцией `open()`. Если выполняемая программа находится в той же папке, что и сам файл, то можно не указывать полный путь к файлу. Однако, в индустрии для однозначности всегда стараются прописывать полный путь к файлу. Поэтому синтаксис у функции вот такой:
# ```
# open(путь_к_файлу_с_именем_файла.расширение_файла)
# # Пример:
# open('MyDrive/my_file.txt')
# ```
#
# Для того, чтобы узнать путь к вашему файлу на Google Drive, откройте меню файлов, найдите нужный вам файл и нажмите ПКМ (правую кнопку мыши), а затем выберите `Скопировать путь`.
#
# Функция `open` не только открывает указанный файл, но еще и создает объект с типом `file` и возвращет его. А если функция что-то возвращает, то значит это можно сохранить в переменную вот таким вот образом:
#
# ```
# my_file = open('MyDrive/my_file.txt')
# ```
#
# А если файла с указанным именем вовсе не существует, то функция `open()` **создаст** его в указанном месте с указанным именем и расширением.
#
# При работе с некоторыми IDE, как PyCharm или VSCode, может возникнуть проблема считывания данных. Это происходит из-различных способов указания пути к файлу. Где-то указывается при помощи прямого слеша `/`, где-то при помощи обратного слеша `\`, где-то при помощи двойного прямого или орбратного слеша: `//` или `\\`. Чтобы избежать неприятных ситуаций с указанием пути, стоит указывать перед названием пути латинскую букву `r`:
# ```
# my_file = open(r'MyDrive/my_file.txt')
# ```
#
# Также вы можете столкнуться с проблемой кодировки различных текстовых файлов. Если вместо русских букв, вы видите кракозябры, то укажите для функции `open()` второй аргумент - тип кодировки текстового файла:
#  ```
# my_file = open(r'MyDrive/my_file.txt', encoding='utf-8')
# ```
# Кодировка `utf-8` как раз таки содержит кириллицу, она должна отобразить ваш текст.

# %% [markdown]
# ### Задача 3. Открыть файл в Python
# Откройте файл `test_file.txt` при помощи функции `open` с вашего Google Drive. Сохраните этот файл в переменную `my_file`.

# %%
# Ваше решение

# %% [markdown]
# ## Чтение файла
# У созданного вами объекта `my_file` теперь есть несколько методов для работы. Первым из них является метод чтения `.read()`. При помощи этого метода можно вывести информацию на экран. Например вот так:
#
# ```
# print(my_file.read())
# ```
#
# ### Задача 4. Выведите текст вашего файла на экран
#
# Примените метод `.read()` и функцию `print()`.

# %%
# Ваше решение

# %% [markdown]
# Метод `.read()` также принимает один аргумент `size`, который отвечает за то, сколько символов из текстового файла будет выведено на экран. Однако, если вызовете этот метод еще раз с данным аргументом, то Python продолжит вывод информации ровно с того места, на котором он остановился на предыдущей итерации. То есть это аналог пишущей каретки. Поэтому, чтобы вывести текст еще раз, необходимо воспользоваться методом `.seek()` и переставить эту каретку в начало текстового файла. Метод принимает аргумент - количество байт от начала файла. Учтите, что все символы в кодировках могут занимать разное количество памяти. Так например, английские буквы в большинстве своем занимают 8 бит информации каждая. А буквы русского алфавита будут занимать 16 бит информации. То есть два байта. Метод seek переставляет побайтово, поэтому для перемещения по буквам русского алфавита нужно это число умножать на 2 и тогда получится перемещаться по тексту из русских букв. Однако, пробелы занимают тоже по одному байту.
#
# ```
# my_file.seek(0) # Переставим каретку в начало
# my_file.seek(10) # Переставим каретку на 10 байт с начала файла.
# ```
#
#
#
# ### Задача 5. Выведите первые 10 символов текста
# Выведите текст еще раз, только на этот раз только первые 10 символов.

# %%
# Ваше решение

fhand = open('task_file.txt')
print(fhand.read(10))
print(fhand.read(10))

fhand.seek(0)
print(fhand.read(10))
fhand.close()
# Out:
# EMAIL, NAM
# E, LAST_NA
# EMAIL, NAM

# %% [markdown]
# Также читать данные из файлы можно построчно при помощи метода `.readline()`. Метод никаких аргументов не принимает. Обратите внимание, что метод работает аналогично методу `.read()` переставляя каретку после считывания очередной строки.
#
# ### Задача 6. Выведите вторую строку файла test_file
# Воспользуйтесь методом `.readline()`

# %%
# Ваше решение

fhand = open('task_file.txt')
a = fhand.readline()
fhand.seek(len(a)+1)
b = fhand.readline()
print(b)
fhand.close()

fhand = open('task_file.txt')
a = fhand.readline()
print(a)
fhand.close()
# Out:
# , Ivan, Abramov, 7776514, Moscow
#
# EMAIL, NAME, LAST_NAME, TEL, CITY

# %% [markdown]
# Конечно же, файл можно обойти при помощи уже знакомого нам цикла `for`. Сделать это можно следующим образом:
#
# ```
# # Цикл для обхода строчек файла
# for строка in имя_файла:
#   print(строка)
#
# # Цикл для обхода символов файла
# for строка in имя_файла:
#   for символ in строка:
#     print(символ)
# ```
#
# ### Задача 7: Все строчки в test_file
# Выведите на экран текст файла test_file. Однако, на каждой строке вначале необходимо указать порядковый номер этой строки. Вот так:
#
# ```
# 1. Мне нравится программировать на Python и решать алгоритмические задачки!
# 2. У меня обязательно все получится!
# ```
#
# Не забудьте переставить каретку для считывания в начало файла.

# %%
# Ваше решение

# %% [markdown]
# ## Закрытие файла
# Обязательным этапом работы с файлами является их закрытие. Если файл не закрыть, то компьютер не освободит место в памяти, которую вы заняли при его открытии в Python. И для этого используют метод `.close()`. Он не принимает никаких аргументов.

# %% [markdown]
# ### Задача 8. Закрытие файла
# Закройте ранее открытый в коллабе файл под именем переменной `my_file`. Если вы сохранили файл в другую переменную, то закройте тогда файл под именем вашей переменной.

# %%
# Ваше решение

# %% [markdown]
# ## Запись в файл
# Аналогично считыванию, мы можем записывать данные в файл при помощи метода `.write()`. В качестве аргумента необходимо указать строковый тип.
#
# Однако, так просто воспользоваться этой функцией у вас не получится. Для того, чтобы это сделать необходимо указать специальный параметр в функции ` open()` при открытии файла.
# Функция ` open()` имеет параметр `mode` который принимает следующие значения:
#
#
# *   `mode='r'` - открытие файла только на чтение
# *   `mode='w'` - открытие файла только на перезапись (данные удаляются и записываются новые данные)
# *   `mode='a'` - открытие файла только на дописывание
#
# У этого параметра есть еще несколько значений. О них вы можете почитать в Google, либо вызвать функцию `help(open)`, либо если просто наведете курсор на функцию в выполняемой ячейке.

# %% [markdown]
# ### Задача 9. Открыть и дозаписать файл
# Откройте меню файловой системы, найдете свой файл test_file и откройте его. Он должен появится в соседнем окне справа.
#
# Теперь откройте файл `test_file` на дозапись данных в колабе. И допишите следующее сообщение с новой строчки:
#
# ```
# А еще мне нравится математика и анализ данных!
# ```
#
# Примечание: чтобы в текстовом файле сделать перенос строки необходимо воспользоваться зарезервированным сочетанием для переноса каретки на новую строку: `\n`
#
# После проделанной операции в окне должен измениться текст. Также после работы с файлом, закройте его при помощи метода `.close()`.

# %%
# Ваше решение

fhand = open('task_file.txt', 'a', encoding='utf-8')
fhand.write('\nКак гений чистой красоты.')
fhand = open('task_file.txt', 'r', encoding='utf-8')
print(fhand.read())
fhand.close()
# Out:
# Я помню чудное мгновенье:
# Передо мной явилась ты,
# Как мимолетное виденье,
# Как гений чистой красоты.

# %% [markdown]
# ### Задача 10. Собственная функция
# Напишите функцию `file_read`, которая принимает полный путь файла, и печатает его содержимое.
#
# Не забудьте закрыть файл после завершения работы!

# %%
# Ваше решение

# %% [markdown]
# ### Задача 11. Создание файлов
# Напишите функцию `create_file_with_numbers`, которая принимает на вход одно целое положительное число - `n`.
#
# Функция должна создать файл с название "range_[number].txt" и наполнить его целыми числами от 1 до n включительно, причем каждое число записывается  в отдельной строке. Не забудьте указать полный пусть к вашей папке на Google Drive.
#
# Пример: функция `create_file_with_numbers(5)` должна создать файл "range_5.txt" с содержимым
#
#
# ```
# 1
# 2
# 3
# 4
# 5
# ```

# %%
# Ваше решение

def create_file_with_numbers(n: int) -> None:
    fhand = open(f'range_{n}.txt', mode='w')
    for i in range(1, n+1):
        fhand.write(str(i) + '\n')
    fhand.close()

create_file_with_numbers(6)

# %% [markdown]
# ### Задача 12*. Поиск самого длинного слова в текстовом файле
#
# Напишите функцию `longest_word_in_file`, которая принимает имя файла и внутри его содержимого находит самое длинное слово и возвращает его в качестве ответа. В случае,  если есть несколько слов с максимальной длиной, нужно вернуть слово, которое встречается последнее в тексте.
#
# При этом слова в тексте отделяются друг от друга пробелами, любые другие знаки пунктуации необходимо исключить.
#
# Все возможные знаки пунктуации можно получить из модуля `string`
#
# ```
# from string import punctuation
# ```

# %%
# Ваше решение

def longest_word_in_file():
    from string import punctuation
    file_name = input('File name: ')
    fhand = open(file_name, 'r', encoding='utf-8')
    longest_word = None
    for line in fhand:
        words = line.split()
        for word in words:
            word = word.rstrip(punctuation)
            if longest_word is None or len(word)>=len(longest_word):
                longest_word = word
    fhand.close()
    return print(longest_word)

longest_word_in_file()
# Out:
# File name: task_file.txt
# мимолетное

# %% [markdown]
# ## Контекстный менеджер
# Как уже было подмечено, важно, чтобы файл всегда закрывался по завершению работы с ним. Однако, это не всегда будет возможно. Например, если в ходе работы с файлом возникла ошибка, то Python может просто не дойти до нужной строчки с закрытием файла:
#
#
# ```
# file = open(file_name)
#
# # Работа с файлом
#
# # Где-то в процессе возникла ошибка
#
# file.close() <- Сюда Python уже не сможет добраться
#
# ```
#
# Это, кстати, один из недостатков интерпретируемых языков программирования.
#
# Однако, в данном случае мы с ним можем бороться двумя способами:
#
# *   Контекстный менеджер
# *   Конструкция `try-except` (об этом позже)
#
# **Контекстный менеджер** - это специальная конструкция управления к внешнему ресурсу. Под внешним ресурсом подразумеваются: базы данных, файлы и т.д. Во всех случаях при работе с внешними ресурсами, к ним сначала нужно *подключиться*, а затем от них *отключиться*. Менеджер контекста нам в этом поможет.
#
# На примере раннее созданного текстового файла давайте разберем работу менеджера контекста. Синтаксис менеджера следующий:
#
#
# ```
# with open('путь_к_файлу/файл.расширение', mode='выбранный режим') as f:
#   # Работа с файлом
#   .....
# # Как только работа с файлом прекращается, либо возникает ошибка, Python сразу же закрывает этот файл автоматически
# ```
#
# `f` в примере выше - это переменная в которой будет хранится наш файл.

# %% [markdown]
# ### Задача 13. Использование контекстного менеджера
# При помощи контекстного менеджера откройте ваш файл и допишите с новой строчки следующую фразу:
#
# ```
# Эта строчка дописана при помощи контектстного менеджера!
# ```
#
# Затем откройте файл и убедитесь в его изменении.

# %%
# Ваше решение

# %% [markdown]
# # 3. Исключения, try, except

# %% [markdown]
# ## Ошибки
# Наверняка за месяц работы с Python вы столкнулись с немалым количеством ошибок в своем коде. И думаю, что очень часто вы не обращали внимание на названия этих ошибок, а также на те подсказки, которые вам выдавал Python для их устранения.
#
# Что ж, сегодня мы познакомимся с ними поближе и перестанем их бояться. Так что же такое ошибка?
#
# **Ошибка** — это неправильное или неточное действие, в результате которого ваша программа либо не запускается вовсе, либо выдает неправильный ответ.
#
# Давайте условно разделим ошибки на три типа:
#
# *  Синтаксическая ошибка
# *  Исключение
# *  Логическая ошибка
#
# **Синтаксическая ошибка** возникает, когда мы не следуем правильной структуре или синтаксису языка. При запуске программы, содержащей  синтаксическую ошибку,  Python сообщит вам, что ваш код не работает, и выдаст информацию об ошибке.
#
# *   Неправильный отсуп (Indentation Error)
#
# ```
# print("Hello")
#     print("my friend")
# ----------------------------------
# IndentationError: unexpected indent
# ```
#
#
# *   Отсутствует двоеточие, запятая или скобки (Syntax Error)
#
# ```
# print("Hello"
# ----------------------------------
# SyntaxError: '(' was never closed
# ```
# При этом программа, в которой есть синтаксические ошибки, даже не запустится. Python о них сообщит сразу, их очень легко исправить и поэтому для нас они не представляют интерес.
#
# Далее, ваша программа запускается, но вдруг падает и вы видите сообщение красного цвета. Значит вы столкнулись с исключением. **Исключения** возникают в процессе выполнения программы. Они являются целью изучения в этом разделе и о них мы поговорим подробнее позже.
#
# А бывает так, что ваша программа программа запускается, в процессе выполнения она не падает в ошибку и даже что-то выводит, но ответ не совпадает с тем, который вы ожидаете. Поздравляю, значит перед вами **логическая ошибка**, или другими словами, с логикой работы вашей программы что-то не так.
#
# Итак, поговорим об исключениях! **Исключение** — это событие, возникающее во время исполнения программы, нарушающее нормальный ход выполнения (например, исключение KeyError Возникает, когда ключ не найден в словаре). Исключение — это объект Python, представляющий ошибку.
#
# В Python исключение — это объект, производный от класса BaseException, содержащий информацию об ошибке, произошедшей в вашей программе. Объект исключения включает в себя:
#
# *   Тип ошибки (имя исключения)
# *   Состояние программы в момент возникновения ошибки
# *   Сообщение об ошибке описывает событие ошибки.
#
# Исключения полезны для указания различных типов возможных условий отказа.
#
# Например, ниже приведены несколько стандартных исключений:
#
# > * FileNotFoundException
# * ImportError
# * RuntimeError
# * NameError
# * TypeError
#
# Это только небольшая часть всех встроенных исключений, но все они являются классами и организуют следующую иерархию:
# ![image.png](data:image/png;base64,...)
# Все исключения наследуются от базового класса BaseException. Но обратите внимание слева на класс Exception, он является родителем всех основных исключений, с которыми мы сталкивается при написании программ. Этот класс Exception нам еще понадобится.

# %% [markdown]
# ## Обработка исключений
# По названию каждого типа исключения можно догадаться, в какой момент данное исключение может произойти. К примеру, исключение NameError возникает при обращении к несуществующей переменной:
#
# ```
# print('1')
# print('2')
# print(value)
# print('3')
# ----------------------------------
# NameError: name 'value' is not defined. Did you mean: 'False'?
# ```
# Здесь программа выполняется поэтапно, согласно заявленным строкам кода, но прерывается в момент возникновения исключения. В данном случае это NameError, т.к. переменная value в программе не объявлена. Также обратите внимание на информацию, которая выводится в момент исключения. Она, повторюсь, включает в себя:
#
# * Тип ошибки (имя исключения)
# * Состояние программы в момент возникновения ошибки
# * Сообщение об ошибке описывает событие ошибки.
#
# Вот пример еще одного исключения. Из школьной математики мы знаем, что на ноль делить нельзя. Такие же правила и в программировании:
# ```
# print(1/0)
# ----------------------------------
# ZeroDivisionError: division by zero
# ```
# Исключения не дают вашей программе выполняться дальше. Они просто останавливают ее выполнение.

# %% [markdown]
# ## `try-except`
# Если вы знаете, что в определенном месте вашего кода можете столкнутся с исключением, то можете  обработать его при помощи блока `try-except`. Пример такой обработки:
#
#
# ```
# print(1)
# print(2)
# try:
#     print(3)
#     print(1/0)
#     print(4)
# except ZeroDivisionError:
#     print('Ошибка деления на ноль!')
# print(5)
# ----------------------------------
# 1
# 2
# 3
# Ошибка деления на ноль!
# 5
# ```
# В данном случае обработалась ошибка типа ZeroDivisionError, для "отлова" которой в блоке except указывается её тип. При исполнении программы она перехватывается и передаётся блоку except для обработки исключения, в нашем случае вывод на экран текста 'Ошибка деления на ноль!'. Далее работа остальной части программы продолжается и корректно завершается.

# %% [markdown]
# ### Вопрос 1. Какой тип исключения получим, если попытаемся обратится к несуществующей переменной?
#
# > Для получения ответа вы можете воспроизвести описанную выше ситуацию в колабе
#
# * ReferenceError
# * AttributeError
# * NameError
# * OSError
# * KeyError
# * MemoryError
# * IndexError
# * KeyboardInterrupt
# * ImportError

# %% [markdown]
# ### Вопрос 2. Какой тип исключения получим, если попытаемся сложить список со строкой или строку с множеством?
#
# > Для получения ответа вы можете воспроизвести описанную выше ситуацию в колабе
#
# * ReferenceError
# * AttributeError
# * NameError
# * OSError
# * KeyError
# * MemoryError
# * IndexError
# * KeyboardInterrupt
# * TypeError

# %%
# Ваш код для проверки исключения

# %% [markdown]
# ### Вопрос 3. Какой тип исключения получим, если попытаемся открыть несуществующий файл?
#
# > Для получения ответа вы можете воспроизвести описанную выше ситуацию в колабе
#
# * IndexError
# * MemoryError
# * FileNotFoundError
# * FileError
# * NameError
# * OSFileError
# * AttributeError

# %%
# Ваш код для проверки исключения

# %% [markdown]
# ### Вопрос 4. Какой тип исключения получим, если попытаемся обратится к несуществующему индексу у строки или у списка?
#
# > Для получения ответа вы можете воспроизвести описанную выше ситуацию в колабе
#
# * IndexError
# * MemoryError
# * IndexOutOfRangeError
# * KeyError
# * ImportError
# * NameError
# * IndexOutError
# * AttributeError

# %%
# Ваш код для проверки исключения

# %% [markdown]
# ### Вопрос 5. Какой тип исключения получим, если попытаемся обратится к несуществующему ключу у словаря?
#
# > Для получения ответа вы можете воспроизвести описанную выше ситуацию в колабе
#
# * IndexError
# * MemoryError
# * IndexOutOfRangeError
# * KeyError
# * ImportError
# * NameError
# * IndexOutError
# * AttributeError

# %%
# Ваш код для проверки исключения

# %% [markdown]
# # 4. Дополнительные модули

# %% [markdown]
# Python на момент октября 2022 все еще самый популярный язык программирования. А потому у него самое большое комьюнити и для него написано огромное количество библиотек. С некоторыми из них вы уже косвенно встречались, с некоторыми познакомитесь на продвинутом уровне обучения.
#
# На продвинутом уровне вам понадобятся такие библиотеки как:
#
# *   `numpy` - библиотека для работы с линейной алгеброй
# *   `matplotlib` - библиотека для работы с графиками
# *   `pandas` - библиотека для работы с анализом данных
#
# Перед тем как вы сможете воспользоваться функциями из этих библиотек, их необходимо установить. Сделать это очень просто. Просто пропишите в ячейке ноутбука:
# ```
# pip install имя_библиотеки
# ```
# Обращаю внимание, что в Google Colab большинство популярных библиотек уже установлено. Проверить какие библиотеки установлены на вашем компьютере или в Google Colab можно командой:
#
# ```
# pip list
# ```
#
# После установки библиотеки её необходимо импортировать в вашу программу. Сделать это можно несколькими способами:
#
# *   Импорт всей библиотеки
# ```
# # Cинтаксис
# import имя_библиотеки
# # Пример импорта
# import numpy
# # Пример использования
# numpy.arrange(15)
# ```
# *   Переименование название библиотеки при импорте (наиболее частый вариант использования)
# ```
# # Cинтаксис
# import имя_библиотеки as сокращенное_имя
# # Пример импорта
# import numpy as np
# # Пример использования
# np.arrange(15)
# ```
# *   Импорт некоторой функции из библиотеки (не рекомендуется, так как теряется название библиотеки и могут возникнуть конфликты с другими функциями и библиотеками)
# ```
# # Cинтаксис
# from имя_библиотеки import имя_Функции
# # Пример импорта
# from numpy import arrange
# # Пример использования
# arrange(15)
# ```
# *   Импорт всех функциий из библиотеки (не рекомендуется, так как теряется название библиотеки и могут возникнуть конфликты с другими функциями и библиотеками)
# ```
# # Cинтаксис
# from имя_библиотеки import *
# # Пример импорта
# from numpy import *
# # Пример использования
# arrange(15)
# ```

# %% [markdown]
# ### Задача 14. Импорт модулей
# Проверьте стоит ли в Google Colab библиотека `numpy`. Установите, если не стоит. Затем импортируйте её в свой ноутбук и воспользуйтесь функцией `linspace`. Найдите документацию к этой библиотеке в интернете и узнайте что делает данная функция.

# %%
# Ваше решение

# %% [markdown]
# # 5. Собственный модуль

# %% [markdown]
# На самом деле любой файл с расширением `.py` - то есть стандартное расширение Python может являться сторонним модулем или библиотекой (это одно и то же).
#
# Давайте попробуем создать свой собственный модуль с одной функцей.

# %% [markdown]
# ### Задача 15. Создание собстенного модуля
#
# Для выполнения данного задания необходимо создать файл со стандартным питоновским расширением `.py`. Поэтому рекомендую вам установить среду VSCode (PyCharm тоже подойдет). Она бесплатная, простая и понятная. О том как это сделать почитать можно вот [здесь](https://code.visualstudio.com/docs/python/python-tutorial).
#
# После успешной установки среды, выполните следующие пункты:
#
# *   Создайте файл `my_library.py`,
# *   В этом файле напишите функцию ` sum_ints`, которая на вход принимает два целых числа и возвращает их сумму. Пропишите аннотации к переменным, а также докстринг для функции,
# *   Загрузите файл во временное сессионное хранилище Google Colab
# *   Импортируйте файл в ноутбук:
# ```
# import my_library
# ```
# *   Воспользуйтесь вашей функцией для сложения двух чисел: 10 и 5
# *   Выведите результат на экран

# %%
# Ваше решение

# %% [markdown]
# # 6. Итоговый проект

# %% [markdown]
# ### Часть I
# В данной задаче вам будет необходимо работать с заранее подготовленным файлом, который можно скачать на платформе по этой [ссылке](https://partner.sberbank-school.ru/programs/15620/item/629278/launch). Текстовый файл находится в ZIP архиве, вам необходимо скачать его, распаковать и переместить текстовый документ в папку, где будет лежать файл с программой для решения данной задачи.
# Файл представляет собой список данных людей со следующими заголовками:
#
# *   EMAIL
# *   NAME
# *   LAST_NAME
# *   TEL
# *   CITY
#
# Столбец EMAIL пустой у всех. Остальные позиции могут быть заполнены или нет.
# Представим следующую ситуацию: вы являетесь сотрудником IT отдела некой компании. Ваша компания открывает новый филиал с переводом необходимого количества сотрудников из разных городов. Новый филиал имеет свой почтовый домен. Вам, как сотруднику IT отдела, необходимо создать каждому сотруднику, переходящему в новый филиал, свой уникальный почтовый адрес. У вас есть неотформатированный список сотрудников, который заполняли непонятно как. Также у вас есть кусок кода - функция, которая по имени и фамилии сотрудника составляет его уникальный почтовый адрес. Для выполнения данного задания вам необходимо написать программу, удовлетворяющую следующим требованиям:
#
# *  Программа должна читать исходный текстовый файл
# *  Программа должна содержать функцию, представленную ниже, для создания почтовых адресов
# *  Программа должна заполнить пустой столбец с почтовыми адресами в исходном файле и перезаписать его
# *  Почтовый адрес должен создаваться только для тех, у кого заполнены все остальные поля - Имя, Фамилия, Телефонный номер, Город
# *  Телефонный номер считается валидным, если он состоит из 7 цифр, в противном случае информация невалидна и программа не должна создавать почтовый адрес сотруднику
#
# После выполнения вашей программы исходный текстовый файл должен быть заполнен информацией с почтовыми адресами сотрудников.
#
# Функция для создания почтовых адресов:
#
# ```
# def email_gen(list_of_names):
#     emails = []
#     for i in list_of_names:
#         letter = 1
#         while i[1] + '.' + i[0][0:letter] + '@company.io' in emails:
#             letter+=1
#         emails.append(i[1] + '.' + i[0][0:letter] + '@company.io')
#     return emails
# ```
#
# Функция принимает список списков **[['Имя_1', 'Фамилия_1'], ['Имя_2', 'Фамилия_2'], ['Имя_3', 'Фамилия_3']]** из имен и фамилий list_of_names. Далее создается пустой список emails, который в ходе выполнения, заполнится почтовыми адресами. Запускается цикл для каждого списка из имени и фамилии **['Имя_1', 'Фамилия_1']**. Устанавливается окончание среза letter = 1. Далее проходит проверка на совпадение, если в списке адресов уже есть такой же адрес (например имя и фамилия сотрудников совпадают), то срез **i[0][0:letter]** увеличивается на 1 символ. После в список адресов добавляется новый адрес. Адреса присваиваются пользователям по следующей формуле: берется фамилия сотрудника, добавляется точка, затем добавляется первая буква имени и остаточная часть **'@company.io'**. Если имена и фамилии сотрудников совпадают, к первой букве имени добавляется вторая и т.д.
#
# Пример выполнения:
# ```
# print(email_gen([['Ivan', 'Petrov'], ['Ivan', 'Petrov'], ['Ivan', 'Petrov']]))
# ['Petrov.I@company.io', 'Petrov.Iv@company.io', 'Petrov.Iva@company.io']
# ```

# %%
# Ваше решение

# %% [markdown]
# ### Часть II*
# Для выполнения данного упражнения вам необходимо использовать некоторые программы из предыдущих упражнений и уроков.
#
# Вам нужно написать программу, которая будет читать файл из предыдущего упражнения, заниматься его чисткой, формировать почтовые адреса для сотрудников, генерировать пароли безопасности для входа в почту, заносить информацию в этот файл и перезаписывать его.
# * Вы можете использовать предыдущие наработки
# *  Ваша программа должна очистить файл от всех невалидных данных (строки с пустыми данными, некорректными именами, некорректными телефонами и городами)
# *  При очистке исходного файла, все невалидные данные должны удаляться из него и сохраняться в отдельный текстовый файл
# *  Поиск информации в файле должен осуществляться с помощью регулярных выражений
# *  Разрешается использовать готовую функцию формирования почтового адреса или написать свою
# *  Сгенерированные пароли должны заноситься в исходный файл в отдельный столбец "PASSWORD"

# %%
# Ваше решение
